# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/image-processing-with-numpy?scriptVersionId=317921881" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🎨 ***Image Processing with NumPy — From Pixels to Computer Vision***
#
# Welcome to this hands-on Image Processing Mini Project using NumPy — where images are no longer just pictures, but powerful numerical data structures waiting to be manipulated and transformed.
#
# In this project, we will dive into the fascinating world of digital image processing by treating images as multidimensional NumPy arrays. Instead of depending entirely on high-level computer vision libraries, we will explore the underlying logic behind common image operations by directly working with pixel values and matrix computations.
#
# Throughout this journey, we will build and apply several real-world image processing techniques, including:
#
# * 🌑 Grayscale Conversion
# * ☀️ Brightness & Contrast Adjustment
# * ✂️ Image Cropping
# * 🎨 RGB Channel Manipulation
# * 🌫️ Blur Effects
# * 🔍 Edge Detection

# %% [markdown]
# ## STEP 1 - Importing essential libraries:

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🪜 STEP 2 — Load Images

# %%
# List of file paths for the images
image_paths = [
    "/kaggle/input/datasets/ahmedfakhar123/image-processing-samples/python.jpg",
    "/kaggle/input/datasets/ahmedfakhar123/image-processing-samples/numpy.png",
    "/kaggle/input/datasets/ahmedfakhar123/image-processing-samples/matplotlib.png"
]

# 1. Load images using PIL
# We use descriptive names to distinguish between PIL objects and NumPy arrays
python_img = Image.open(image_paths[0])
numpy_img = Image.open(image_paths[1])
matplotlib_img = Image.open(image_paths[2])

# 2. Pre-processing: Convert to RGB
# This ensures all images have 3 channels (Red, Green, Blue) 
# and removes Alpha (transparency) channels often found in PNGs
python_img_rgb = python_img.convert('RGB')
numpy_img_rgb = numpy_img.convert('RGB')
matplotlib_img_rgb = matplotlib_img.convert('RGB')

# 3. Convert PIL images to NumPy arrays for processing
python_arr = np.array(python_img_rgb)
numpy_arr = np.array(numpy_img_rgb)
matplotlib_arr = np.array(matplotlib_img_rgb)

# 4. Display image dimensions
# The shape will now consistently be (Height, Width, 3)
print("--- Image Dimensions (Height, Width, Channels) ---")
print(f"Python Logo:     {python_arr.shape}")
print(f"NumPy Logo:      {numpy_arr.shape}")
print(f"Matplotlib Logo: {matplotlib_arr.shape}")
# Out:
# --- Image Dimensions (Height, Width, Channels) ---
# Python Logo:     (168, 299, 3)
# NumPy Logo:      (150, 335, 3)
# Matplotlib Logo: (628, 1200, 3)
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %% [markdown]
# ### Showing Images:

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(python_arr)
plt.title("Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(numpy_arr)
plt.title("NumPy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(matplotlib_arr)
plt.title("Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 🌑 STEP 3 — Convert to Grayscale
#
# ### Concept:
#
# Average RGB channels.
#
# ### Formula:
#
# $$\text{Gray} = \frac{R + G + B}{3}$$
#
# ### Code:

# %%
grayscale1 = python_arr.mean(axis=2)
grayscale2 = numpy_arr.mean(axis=2)
grayscale3 = matplotlib_arr.mean(axis=2)


plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(grayscale1, cmap='gray')
plt.title("Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(grayscale2, cmap='gray')
plt.title("Numpy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(grayscale3, cmap='gray')
plt.title("Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ☀️ STEP 3 — Brightness Adjustment
#
# ### Increase brightness:

# %%
bright_python = np.clip(python_arr.astype(np.int32) + 100, 0, 255).astype(np.uint8)
bright_numpy = np.clip(numpy_arr.astype(np.int32) + 100, 0, 255).astype(np.uint8)
bright_matplotlib = np.clip(matplotlib_arr.astype(np.int32) + 100, 0, 255).astype(np.uint8)

plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(bright_python)
plt.title("Bright Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(bright_numpy)
plt.title("Bright Numpy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(bright_matplotlib)
plt.title("Bright Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Decrease Brightness:

# %%
dull_python = np.clip(python_arr.astype(np.int32) - 100, 0, 255).astype(np.uint8)
dull_numpy = np.clip(numpy_arr.astype(np.int32) - 100, 0, 255).astype(np.uint8)
dull_matplotlib = np.clip(matplotlib_arr.astype(np.int32) - 100, 0, 255).astype(np.uint8)

plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(dull_python)
plt.title("Dull Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(dull_numpy)
plt.title("Dull Numpy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(dull_matplotlib)
plt.title("Dull Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🎭 STEP 4 — Negative Image

# %%
inverted_python = 255 - python_arr
inverted_numpy = 255 - numpy_arr
inverted_matplotlib = 255 - matplotlib_arr

plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(inverted_python)
plt.title("Inverted Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(inverted_numpy)
plt.title("Inverted Numpy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(inverted_matplotlib)
plt.title("Inverted Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🌫️ STEP 5 — Blur Effect

# %%
'''
blur_python = np.zeros_like(python_arr)
blur_numpy = np.zeros_like(numpy_arr)
blur_matplotlib = np.zeros_like(matplotlib_arr)

for i in range(3, python_arr.shape[0]-3):
    for j in range(3, python_arr.shape[1]-3):
        window = python_arr[i-3:i+4, j-3:j+4]
        blur_python[i, j] = np.mean(window, axis=(0,1))

for i in range(3, numpy_arr.shape[0]-3):
    for j in range(3, numpy_arr.shape[1]-3):
        window = numpy_arr[i-3:i+4, j-3:j+4]
        blur_numpy[i, j] = np.mean(window, axis=(0,1))
       
for i in range(11, matplotlib_arr.shape[0]-11):
    for j in range(11, matplotlib_arr.shape[1]-11):
        window = matplotlib_arr[i-11:i+12, j-11:j+12]
        blur_matplotlib[i, j] = np.mean(window, axis=(0,1))
       
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(blur_python)
plt.title("Blur Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(blur_numpy)
plt.title("Blur Numpy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(blur_matplotlib)
plt.title("Blur Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()
'''
# Out:
# '\nblur_python = np.zeros_like(python_arr)\nblur_numpy = np.zeros_like(numpy_arr)\nblur_matplotlib = np.zeros_like(matplotlib_arr)\n\nfor i in range(3, python_arr.shape[0]-3):\n    for j in range(3, python_arr.shape[1]-3):\n        window = python_arr[i-3:i+4, j-3:j+4]\n        blur_python[i, j] = np.mean(window, axis=(0,1))\n\nfor i in range(3, numpy_arr.shape[0]-3):\n    for j in range(3, numpy_arr.shape[1]-3):\n        window = numpy_arr[i-3:i+4, j-3:j+4]\n        blur_numpy[i, j] = np.mean(window, axis=(0,1))\n       \nfor i in range(11, matplotlib_arr.shape[0]-11):\n    for j in range(11, matplotlib_arr.shape[1]-11):\n        window = matplotlib_arr[i-11:i+12, j-11:j+12]\n        blur_matplotlib[i, j] = np.mean(window, axis=(0,1))\n       \nplt.figure(figsize=(20, 5))\n\nplt.subplot(1, 3, 1)\nplt.imshow(blur_python)\nplt.title("Blur Python")\nplt.axis("off")\n\nplt.subplot(1, 3, 2)\nplt.imshow(blur_numpy)\nplt.title("Blur Numpy")\nplt.axis("off")\n\nplt.subplot(1, 3, 3)\nplt.ims
# ...

# %% [markdown]
# ## ✂️ STEP 6 — Crop Image

# %%
crop_python = python_arr[50:300, 100:300]
crop_numpy = numpy_arr[50:300, 50:300]
crop_matplotlib = matplotlib_arr[350:500, 350:500]

plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(crop_python)
plt.title("Crop Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(crop_numpy)
plt.title("Crop Numpy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(crop_matplotlib)
plt.title("Crop Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔍 STEP 7 — Edge Detection

# %%
edges_python = np.diff(grayscale1, axis=0)
edges_numpy = np.diff(grayscale2, axis=0)
edges_matplotlib = np.diff(grayscale3, axis=0)

plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
plt.imshow(edges_python, cmap='gray')
plt.title("Edges Python")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(edges_numpy, cmap='gray')
plt.title("Edges Numpy")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(edges_matplotlib, cmap='gray')
plt.title("Edges Matplotlib")
plt.axis("off")

plt.tight_layout()
plt.show()
